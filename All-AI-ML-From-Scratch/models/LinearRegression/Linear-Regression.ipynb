# %%
print('hello')
# Out:
# hello

# %%
import altair as alt

# load a simple dataset as a pandas DataFrame
from altair.datasets import data
cars = data.cars()

alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       1 import altair as alt
#       3 # load a simple dataset as a pandas DataFrame
# ----> 4 from altair.datasets import data
#       5 cars = data.cars()
#       7 alt.Chart(cars).mark_point().encode(
#       8     x='Horsepower',
#       9     y='Miles_per_Gallon',
#      10     color='Origin',
#      11 )
#
# ModuleNotFoundError: No module named 'altair.datasets'
