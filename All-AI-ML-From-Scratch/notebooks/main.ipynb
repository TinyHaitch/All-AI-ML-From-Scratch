# %%
# import import_ipynb
from base_model import BaseModel

# %%
model = BaseModel()

# %%
X = [1, 2, 3, 4]
print(model.predict(X))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 X = [1, 2, 3, 4]
# ----> 2 print(model.predict(X))
#
# File <string>:50, in predict(self, X)
#
# NotImplementedError: Subclasses must implement predict()
